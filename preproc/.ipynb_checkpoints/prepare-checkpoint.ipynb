# %%
import os
import pandas as pd
from utils import stem
import json

# %%
PARENT_PATH = os.path.join("..")
DATASET_CSV = os.path.join(PARENT_PATH, "data", "analyzed.csv")
RESULT_CSV = os.path.join(PARENT_PATH, "data", "prepared.csv")
TAGS_TXT = os.path.join(PARENT_PATH, "data", "tags.txt")

# %%
with open(TAGS_TXT, 'r') as fr:
    TAGS = json.load(fr)

# %%
df_prepare = pd.read_csv(DATASET_CSV, index_col=0)

# %%
df_prepare.head()
# Out:
#                                                  text  \
# 1     \nПисатель и критик соотносятся так же, как ...
# 2     Привет всем пикабушникам, этим холодным 1-се...
# 5     \nА она идеальна! От щиколоток до кончиков р...
# 6     \nПродолжаю истории про моего друга.Естестве...
# 11    История не то, чтобы юмористическая, но посм...
#
#                                                  tags
# 1   ['Не мое', 'Чтение', 'Книги', 'Литература', 'Д...
# 2   ['Компьютер', 'Компьютерщики', 'Компьютерное ж...
# 5   ['[моё]', 'Советы 30-летнего', 'Френдзона', 'О...
# 6   ['[моё]', 'Китай', 'Таможня', 'Деньги', 'Истор...
# 11  ['История', 'Деньги', 'Сложный выбор', 'Текст'...

# %%
df_prepare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79104 entries, 1 to 668256
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    79104 non-null  object
#  1   tags    79104 non-null  object
# dtypes: object(2)
# memory usage: 1.8+ MB

# %%
# %%time
df_prepare["text_stem"] = df_prepare[["text"]].apply(lambda row: stem(row["text"]), axis=1)
# Out:
# CPU times: user 7min 46s, sys: 8.23 s, total: 7min 54s
# Wall time: 8min 5s

# %%
def has_tag(tags_data, tag):
    tags = tags_data.strip("[]").replace("'", "").split(', ')
    if tag in tags:
        return 1
    else:
        return 0

# %%
df = df_prepare[["text_stem", "tags"]].dropna()

# %%
for tag in TAGS:
    df[tag] = df[["tags"]].apply(lambda row: has_tag(row["tags"], tag), axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79104 entries, 1 to 668256
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   text_stem         79104 non-null  object
#  1   tags              79104 non-null  object
#  2   Рассказ           79104 non-null  int64
#  3   История           79104 non-null  int64
#  4   Украина           79104 non-null  int64
#  5   Россия            79104 non-null  int64
#  6   Политика          79104 non-null  int64
#  7   Моё               79104 non-null  int64
#  8   Не мое            79104 non-null  int64
#  9   Юмор              79104 non-null  int64
#  10  Длиннотекст       79104 non-null  int64
#  11  Работа            79104 non-null  int64
#  12  Крипота           79104 non-null  int64
#  13  Мат               79104 non-null  int64
#  14  Жизнь             79104 non-null  int64
#  15  Истории из жизни  79104 non-null  int64
#  16  Отношения         79104 non-null  int64
#  17  Дети              79104 non-null  int64
#  18  США               79104 non-null  int64
# dtypes: int64(17), object(2)
# memory usage: 12.1+ MB

# %%
df.head()
# Out:
#                                             text_stem  \
# 1   Писател критик соотнос же, астрон астролог. Ка...
# 2   Привет всем пикабушникам, эт холодн 1-сентябрь...
# 5   А идеальна! От щиколоток кончик ресниц. Есть н...
# 6   Продолжа истор мо друга.Естествен ег лица:Давн...
# 11  Истор то, юмористическая, посмея пар мест наве...
#
#                                                  tags  Рассказ  История  \
# 1   ['Не мое', 'Чтение', 'Книги', 'Литература', 'Д...        0        0
# 2   ['Компьютер', 'Компьютерщики', 'Компьютерное ж...        0        0
# 5   ['[моё]', 'Советы 30-летнего', 'Френдзона', 'О...        0        0
# 6   ['[моё]', 'Китай', 'Таможня', 'Деньги', 'Истор...        0        1
# 11  ['История', 'Деньги', 'Сложный выбор', 'Текст'...        0        1
#
#     Украина  Россия  Политика  Моё  Не мое  Юмор  Длиннотекст  Работа  \
# 1         0       0         0    0       1     0            0       0
# 2         0       0         0    0       0     0            0       0
# 5         0       0         0    0       0     0            0       0
# 6         0       0         0    0       0     0            0       0
# 11        0       0         0    0       0     0            0       0
#
#     Крипота  Мат  Жизнь  Истории из жизни  Отношения  Дети  США
# 1         0    0      0                 0          0     0    0
# 2         0    0      0                 0          0     0    0
# 5         0    0      0                 0          1     0    0
# 6         0    0      0                 0          0     0    0
# 11        0    0      0                 0          0     0    0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
categories = list(df.columns.values)[2:]
sns.set(font_scale = 2)
plt.figure(figsize=(45,4))
ax= sns.barplot(categories, df.iloc[:,2:].sum().values)
plt.title("Posts with each tag", fontsize=24)
plt.ylabel('Number of posts', fontsize=18)
plt.xlabel('Tag name ', fontsize=18)

rects = ax.patches
labels = df.iloc[:,2:].sum().values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=18)
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
rowSums = df.iloc[:,2:].sum(axis=1)
multiLabel_counts = rowSums.value_counts()
multiLabel_counts = multiLabel_counts.iloc[1:]
sns.set(font_scale = 2)
plt.figure(figsize=(15,8))
ax = sns.barplot(multiLabel_counts.index, multiLabel_counts.values)
plt.title("Posts having multiple labels ")
plt.ylabel('Number of posts', fontsize=18)
plt.xlabel('Number of tags', fontsize=18)

rects = ax.patches
labels = multiLabel_counts.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.to_csv(RESULT_CSV)
